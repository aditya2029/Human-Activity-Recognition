# %% [markdown]
# # Human Activity Recognition
#
# This project is to build a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying.

# %% [markdown]
# Readings are divided into window of 2.56 seconds with 50% overlap.

# %% [markdown]
# ## Problem Statement:
#
# Given a datapoint, we have to predict the activity.

# %%
import numpy as np
import pandas as pd

features = list()

with open('UCI_HAR_Dataset/features.txt') as f:
    
    features = [line.split()[1] for line in f.readlines()]

print("Number of features: ",len(features))
# Out:
# Number of features:  561

# %%
# get the data from txt files to pandas dataffame
X_train = pd.read_csv('UCI_HAR_dataset/train/X_train.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_train['subject'] = pd.read_csv('UCI_HAR_dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('UCI_HAR_dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample()
# Out:
# C:\Users\aditya pandey\Anaconda3\lib\site-packages\pandas\io\parsers.py:678: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 1048           0.274674          -0.012459          -0.101213
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 1048         -0.988972         -0.980884         -0.958913         -0.990177
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X      ...       \
# 1048         -0.979992         -0.957786         -0.931487      ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 1048                     0.045003                             -0.075691
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 1048                          0.060361                             -0.134028
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 1048             -0.817576              0.108618             -0.114554
#
#       subject  Activity  ActivityName
# 1048        6         4       SITTING
#
# [1 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %%
train.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        7352.000000        7352.000000        7352.000000
# mean            0.274488          -0.017695          -0.109141
# std             0.070261           0.040811           0.056635
# min            -1.000000          -1.000000          -1.000000
# 25%             0.262975          -0.024863          -0.120993
# 50%             0.277193          -0.017219          -0.108676
# 75%             0.288461          -0.010783          -0.097794
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       7352.000000       7352.000000       7352.000000       7352.000000
# mean          -0.605438         -0.510938         -0.604754         -0.630512
# std            0.448734          0.502645          0.418687          0.424073
# min           -1.000000         -0.999873         -1.000000         -1.000000
# 25%           -0.992754         -0.978129         -0.980233         -0.993591
# 50%           -0.946196         -0.851897         -0.859365         -0.950709
# 75%           -0.242813         -0.034231         -0.262415         -0.292680
# max            1.000000          0.916238          1.000000          1.000000
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X     ...       \
# count       7352.000000       7352.000000       7352.000000     ...
# mean          -0.526907         -0.606150         -0.468604     ...
# std            0.485942          0.414122          0.544547     ...
# min           -1.000000         -1.000000         -1.000000     ...
# 25%           -0.978162         -0.980251         -0.936219     ...
# 50%           -0.857328         -0.857143         -0.881637     ...
# 75%           -0.066701         -0.265671         -0.017129     ...
# max            0.967664          1.000000          1.000000     ...
#
#        fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# count                      7352.000000                  7352.000000
# mean                         -0.625294                     0.008684
# std                           0.307584                     0.336787
# min                          -0.999765                    -0.976580
# 25%                          -0.845573                    -0.121527
# 50%                          -0.711692                     0.009509
# 75%                          -0.503878                     0.150865
# max                           0.956845                     1.000000
#
#        angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# count                           7352.000000                       7352.000000
# mean                               0.002186                          0.008726
# std                                0.448306                          0.608303
# min                               -1.000000                         -1.000000
# 25%                               -0.289549                         -0.482273
# 50%                                0.008943                          0.008735
# 75%                                0.292861                          0.506187
# max                                1.000000                          0.998702
#
#        angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# count                           7352.000000           7352.000000
# mean                              -0.005981             -0.489547
# std                                0.477975              0.511807
# min                               -1.000000             -1.000000
# 25%                               -0.376341             -0.812065
# 50%                               -0.000368             -0.709417
# 75%                                0.359368             -0.509079
# max                                0.996078              1.000000
#
#        angle(Y,gravityMean)  angle(Z,gravityMean)      subject     Activity
# count           7352.000000           7352.000000  7352.000000  7352.000000
# mean               0.058593             -0.056515    17.413085     3.643362
# std                0.297480              0.279122     8.975143     1.744802
# min               -1.000000             -1.000000     1.000000     1.000000
# 25%               -0.017885             -0.143414     8.000000     2.000000
# 50%                0.182071              0.003181    19.000000     4.000000
# 75%                0.248353              0.107659    26.000000     5.000000
# max                0.478157              1.000000    30.000000     6.000000
#
# [8 rows x 563 columns]

# %%
# Obtain test data

# get the data from txt files to pandas dataffame
X_test = pd.read_csv('UCI_HAR_dataset/test/X_test.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_test['subject'] = pd.read_csv('UCI_HAR_dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('UCI_HAR_dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
# C:\Users\aditya pandey\Anaconda3\lib\site-packages\pandas\io\parsers.py:678: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
#      tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 385           0.260936          -0.009344           -0.09099
#
#      tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 385         -0.492149         -0.187293         -0.615148          -0.51223
#
#      tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X      ...       \
# 385         -0.219922         -0.620571         -0.312874      ...
#
#      angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 385                      0.25221                              0.482238
#
#      angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 385                          0.901047                             -0.122012
#
#      angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 385             -0.833651              0.157075             -0.085663
#
#      subject  Activity  ActivityName
# 385        4         1       WALKING
#
# [1 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Check for duplicates

# %%
print("Number of duplicates in train {}".format(sum(train.duplicated())))
print("Number of duplicates in train {}".format(sum(test.duplicated())))
# Out:
# Number of duplicates in train 0
# Number of duplicates in train 0

# %% [markdown]
# ### Check for NaN values

# %%
print("we have {} NaN values is train".format(train.isnull().values.sum()))
print("we have {} NaN values is test".format(test.isnull().values.sum()))
# Out:
# we have 0 NaN values is train
# we have 0 NaN values is test

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Our data is well balanced

# %% [markdown]
# ## Changing features name

# %%
columns = train.columns

columns = columns.str.replace("[()]","")
columns = columns.str.replace("[-]","")
columns = columns.str.replace("[,]","")

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %%
train.to_csv('UCI_HAR_Dataset/csv_files/train.csv', index=False)
test.to_csv('UCI_HAR_Dataset/csv_files/test.csv', index=False)

# %%
train.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# #### Static Activities :
# Sitting, Standing and Laying
# #### Dynamic Activities :
# Walking, WalkingUpstairs, WalkingDownStairs

# %%
sns.set_palette("Set1",desat=0.80)
facetgrid = sns.FacetGrid(train, hue="ActivityName",size=6, aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()

plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# C:\Users\aditya pandey\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# taking each activity in different dataframe

df1 = train[train["Activity"]==1]
df2 = train[train["Activity"]==2]
df3 = train[train["Activity"]==3]
df4 = train[train["Activity"]==4]
df5 = train[train["Activity"]==5]
df6 = train[train["Activity"]==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()
# Out:
# C:\Users\aditya pandey\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Magnitude of acceleration (BoxPlot)

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x="ActivityName", y="tBodyAccMagmean", data = train, showfliers=False, saturation = 1 )
plt.ylabel("Acceleration Magnitude Mean")
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# __ Observations__:
# - If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# - If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# - If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# - We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ## Plotting data of Gravity Mean

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# __ Observations__:
# * If angleX,gravityMean > 0 then Activity is Laying.
# * We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# ## Apply TSNE on Data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def perform_tsne(X_data, Y_data, perplexity, n_iter=1000, img_name_prefix="t-sne"):
    
    X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
    
    df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':Y_data})
    
    sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
    palette="Set1",markers=['^','v','s','o', '1','2'])
    plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
    img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
    print('saving this plot as image in present working directory...')
    plt.savefig(img_name)
    plt.show()
    print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne, Y_data = y_pre_tsne, perplexity=5)
# Out:
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.788s...
# [t-SNE] Computed neighbors for 7352 samples in 75.596s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.170s
# [t-SNE] Iteration 50: error = 114.2714691, gradient norm = 0.0222766 (50 iterations in 42.266s)
# [t-SNE] Iteration 100: error = 97.6924591, gradient norm = 0.0156538 (50 iterations in 17.659s)
# [t-SNE] Iteration 150: error = 93.2316132, gradient norm = 0.0101729 (50 iterations in 13.382s)
# [t-SNE] Iteration 200: error = 91.1517563, gradient norm = 0.0067861 (50 iterations in 13.220s)
# [t-SNE] Iteration 250: error = 89.9492645, gradient norm = 0.0059802 (50 iterations in 13.191s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.949265
# [t-SNE] Iteration 300: error = 3.5706668, gradient norm = 0.0014617 (50 iterations in 12.940s)
# [t-SNE] Iteration 350: error = 2.8130507, gradient norm = 0.0007518 (50 iterations in 12.911s)
# [t-SNE] Iteration 400: error = 2.4336247, gradient norm = 0.0005257 (50 iterations in 13.038s)
# [t-SNE] Iteration 450: error = 2.2162199, gradient norm = 0.0004072 (50 iterations in 13.100s)
# [t-SNE] Iteration 500: error = 2.0718992, gradient norm = 0.0003291 (50 iterations in 13.217s)
# [t-SNE] Iteration 550: error = 1.9667889, gradient norm = 0.0002817 (50 iterations in 13.382s)
# [t-SNE] Iteration 600: error = 1.8855157, gradient norm = 0.0002479 (50 iterations in 13.228s)
# [t-SNE] Iteration 650: error = 1.8201232, gradient norm = 0.0002207 (50 iterations in 12.660s)
# [t-SNE] Iteration 700: error = 1.7664472, gradient norm = 0.0001992 (50 iterations in 12.750s)
# [t-SNE] Iteration 750: error = 1.7211083, gradient norm = 0.0001791 (50 iterations in 12.800s)
# [t-SNE] Iteration 800: error = 1.6821059, gradient norm = 0.0001657 (50 iterations in 12.687s)
# [t-SNE] Iteration 850: error = 1.6479603, gradient norm = 0.0001536 (50 iterations in 12.814s)
# [t-SNE] Iteration 900: error = 1.6179138, gradient norm = 0.0001440 (50 iterations in 12.909s)
# [t-SNE] Iteration 950: error = 1.5914192, gradient norm = 0.0001351 (50 iterations in 12.892s)
# [t-SNE] Iteration 1000: error = 1.5676078, gradient norm = 0.0001257 (50 iterations in 12.919s)
# [t-SNE] Error after 1000 iterations: 1.567608
# saving this plot as image in present working directory...
# Done
